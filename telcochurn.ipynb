# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #READING DATA FROM CSV FILE

# %%
df = pd.read_csv('custchurn.csv')
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %% [markdown]
# #DATA ANALYSIS

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
labels =df['Churn'].value_counts(sort = True).index
sizes = df['Churn'].value_counts(sort = True)


colors = ["whitesmoke","red"]
explode = (0.1,0)  # explode 1st slice
 

# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=270,)

plt.title('Percent of churn in customer')
plt.show()

# %%
services = ['PhoneService','MultipleLines','InternetService','OnlineSecurity',
           'OnlineBackup','DeviceProtection','TechSupport','StreamingTV','StreamingMovies']

fig, axes = plt.subplots(nrows = 3,ncols = 3,figsize = (15,12))
for i, item in enumerate(services):
    if i < 3:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i,0],rot = 0)
        
    elif i >=3 and i < 6:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-3,1],rot = 0)
        
    elif i < 9:
        ax = df[item].value_counts().plot(kind = 'bar',ax=axes[i-6,2],rot = 0)
    ax.set_title(item)

# %%
for CONTENT in df.columns:
  print( df[CONTENT].value_counts())
# Out:
# 7779-ORAEL    1
# 3902-FOIGH    1
# 3870-SPZSI    1
# 0902-XKXPN    1
# 9625-RZFUK    1
# 4940-KHCWD    1
# 4423-JWZJN    1
# 5485-WUYWF    1
# 0224-NIJLP    1
# 9722-UJOJR    1
# 0103-CSITQ    1
# 2294-DMMUS    1
# 7244-QWYHG    1
# 2874-YXVVA    1
# 0840-DFEZH    1
# 9817-APLHW    1
# 7980-MHFLQ    1
# 9355-NPPFS    1
# 3308-JSGML    1
# 2018-QKYGT    1
# 3845-FXCYS    1
# 1666-JXLKU    1
# 7074-IEVOJ    1
# 2911-WDXMV    1
# 2911-IJORQ    1
# 5156-UMKOW    1
# 3318-NMQXL    1
# 7609-NRNCA    1
# 3295-YVUSR    1
# 3224-DFQNQ    1
#              ..
# 8690-UPCZI    1
# 8785-CJSHH    1
# 4765-OXPPD    1
# 3199-NPKCN    1
# 1241-FPMOF    1
# 1356-MKYSK    1
# 5020-ZSTTY    1
# 7312-XSBAT    1
# 6496-JDSSB    1
# 6837-HAEVO    1
# 7319-ZNRTR    1
# 3030-YDNRM    1
# 9842-EFSYY    1
# 4143-HHPMK    1
# 4713-ZBURT    1
# 4821-SJHJV    1
# 8979-CAMGB    1
# 6743-HHQPF    1
# 9629-NHXFW    1
# 2604-XVDAM    1
# 4873-ILOLJ    1
# 0895-DQHEW    1
# 7157-SMCFK    1
# 8570-KLJYJ    1
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# #CONVERSION OF NON NUMERIC CLASS TO NUMERIC CLASS

# %%
df['TotalCharges'] = pd.to_numeric(df.TotalCharges, errors='coerce')
df=df.dropna()
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %% [markdown]
# #seperation of dependent and independent variables

# %%
#seperation of dependent and independent variables
lables=df.iloc[:,-1]
lables
features=df.iloc[:,1:20]
features.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
lables = labelencoder.fit_transform(lables)
lables
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
df.Contract.value_counts()
# Out:
# Month-to-month    3875
# Two year          1685
# One year          1472
# Name: Contract, dtype: int64

# %% [markdown]
# #ENCODING THE CATOGORICAL VARIABLE

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
features['gender']=labelencoder.fit_transform(features['gender'])
features.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0       0              0     Yes         No       1           No
# 1       1              0      No         No      34          Yes
# 2       1              0      No         No       2          Yes
# 3       1              0      No         No      45           No
# 4       0              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
for CONTENT in features.columns:
  print(features[CONTENT].value_counts())
# Out:
# 1    3549
# 0    3483
# Name: gender, dtype: int64
# 0    5890
# 1    1142
# Name: SeniorCitizen, dtype: int64
# No     3639
# Yes    3393
# Name: Partner, dtype: int64
# No     4933
# Yes    2099
# Name: Dependents, dtype: int64
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
# 71    170
# 5     133
# 7     131
# 8     123
# 70    119
# 9     119
# 12    117
# 10    116
# 6     110
# 13    109
# 68    100
# 15     99
# 11     99
# 67     98
# 18     97
# 69     95
# 24     94
# 22     90
# 66     89
# 35     88
# 17     87
# 23     85
# 16     80
# 64     80
# 52     80
#      ...
# 29     72
# 20     71
# 53     70
# 62     70
# 41     70
# 32     69
# 47     68
# 51     68
# 54     68
# 50     68
# 58     67
# 49     66
# 57     65
# 37     65
# 31     65
# 43     65
# 34     65
# 42     65
# 40     64
# 48     64
# 33     64
# 55     64
# 21     63
# 45     61
# 59     60
# 38     59
# 28     57
# 39     56
# 44     51
# 36     50
# ...

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder = LabelEncoder()
features['PaymentMethod']=labelencoder.fit_transform(features['PaymentMethod'])                                       
labelencoder = LabelEncoder()
features['PaperlessBilling']=labelencoder.fit_transform(features['PaperlessBilling'])
labelencoder = LabelEncoder()
features['Contract']=labelencoder.fit_transform(features['Contract'])
labelencoder = LabelEncoder()
features['StreamingMovies']=labelencoder.fit_transform(features['StreamingMovies'])
labelencoder = LabelEncoder()
features['StreamingTV']=labelencoder.fit_transform(features['StreamingTV'])
labelencoder = LabelEncoder()
features['TechSupport']=labelencoder.fit_transform(features['TechSupport'])
labelencoder = LabelEncoder()
features['DeviceProtection']=labelencoder.fit_transform(features['DeviceProtection'])
labelencoder = LabelEncoder()
features['OnlineBackup']=labelencoder.fit_transform(features['OnlineBackup'])
labelencoder = LabelEncoder()
features['InternetService']=labelencoder.fit_transform(features['InternetService'])
labelencoder = LabelEncoder()
features['OnlineSecurity']=labelencoder.fit_transform(features['OnlineSecurity'])
labelencoder = LabelEncoder()
features['Dependents']=labelencoder.fit_transform(features['Dependents'])
labelencoder = LabelEncoder()
features['PhoneService']=labelencoder.fit_transform(features['PhoneService'])
labelencoder = LabelEncoder()
features['MultipleLines']=labelencoder.fit_transform(features['MultipleLines'])

# %%
labelencoder = LabelEncoder()
features['Partner']=labelencoder.fit_transform(features['Partner'])
features
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# 5          0              0        0           0       8             1
# 6          1              0        0           1      22             1
# 7          0              0        0           0      10             0
# 8          0              0        1           0      28             1
# 9          1              0        0           1      62             1
# 10         1              0        1           1      13             1
# 11         1              0        0           0      16             1
# ...

# %%
# tenure distibution 
labelencoder = LabelEncoder()
df['Churn']= labelencoder.fit_transform(df['Churn'])

g = sns.kdeplot(df.tenure[(df["Churn"] == 0) ], color="Red", shade = True)
g = sns.kdeplot(df.tenure[(df["Churn"] == 1) ], ax =g, color="Blue", shade= True)
g.set_xlabel("tenure")
g.set_ylabel("Frequency")
plt.title('Distribution of tenure comparing with churn feature')
g = g.legend(["Not Churn","Churn"])

# %% [markdown]
# #SCALING THE VARIABLES

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, lables, features.index, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train = sc_X.fit_transform(X_train)
X_test= sc_X.transform(X_teifier
model = XGBClassifier()st)

# %% [markdown]
# #LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(random_state=35)
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)


from sklearn.metrics import confusion_matrix
import seaborn as sns
conf_mat = confusion_matrix(y_test, y_pred)
print(conf_mat)
sns.heatmap(conf_mat, annot=True, fmt='d',
            xticklabels=['yes','no'], yticklabels=['yes','yes'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# [[933 105]
#  [169 200]]
# accuracy: 0.805259

# %% [markdown]
# #RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split


model = RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0)
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
           xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.798152

# %% [markdown]
# #NAIVE BAYES

# %%
#@title Default title text
from sklearn.naive_bayes import MultinomialNB
model =MultinomialNB()
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, lables, features.index, test_size=0.2, random_state=0)
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
           xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.647477

# %% [markdown]
# #DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
model =DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
           xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.719972

# %% [markdown]
# #KNN

# %%
#knn
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifieifier
model = XGBClassifier()r(n_neighbors=3)
#y_pred_proba = model.predict_proba(X_test)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
          xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.751955

# %% [markdown]
# #xgboost

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
          xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.806681

# %% [markdown]
# #ADABOOSTCLASSIFIER

# %%
from sklearn.ensemble import AdaBoostClassifier
model = AdaBoostClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
          xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.800995

# %% [markdown]
# #LIGHTGBM

# %%
from lightgbm import LGBMClassifier
model = LGBMClassifier(random_state=5)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
          xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.795309

# %% [markdown]
# ###we are getting maximum performance in  logestice regression and xgboost and random forest so i am applying parameter tuning for these three models

# %% [markdown]
# #Parmeter Tuning

# %% [markdown]
# ##parameter tuning in random forest

# %%
from sklearn.model_selection import  cross_val_score,GridSearchCV
param_grid  = { 
                'n_estimators' : [200,500,1200],
               # 'min_samples_split': [2,5,10,15,100],
               # 'min_samples_leaf': [1,2,5,10],
                'max_depth': range(1,5),
                'max_features' : ('log2', 'sqrt'),
                'class_weight':[{1: w} for w in [1,1.5]]
              }

model = GridSearchCV(RandomForestClassifier(random_state=35), param_grid)
model.fit(X_train,y_train)
print(
    #'DecisionTree: Area under the ROC curve = {}'.format(RF_performance)
     "\nBest parameters \n" + str(model.best_params_))
# Out:
# Best parameters
# {'class_weight': {1: 1.5}, 'max_depth': 4, 'max_features': 'log2', 'n_estimators': 200}

# %%
model1 = RandomForestClassifier(random_state=35,**model.best_params_)
model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
          xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.786780

# %% [markdown]
# ##parameter tuning in logestic regression

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
model = GridSearchCV(LogisticRegression(random_state=35,penalty='l2'), param_grid)
model.fit(X_train,y_train)
print(
    #'DecisionTree: Area under the ROC curve = {}'.format(RF_performance)
     "\nBest parameters \n" + str(model.best_params_))
# Out:
# Best parameters
# {'C': 0.01}

# %%
model1 = LogisticRegression(random_state = 0,penalty='l2',C=0.01)
model1.fit(X_train, y_train)
y_pred = model1.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
          xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.805259

# %% [markdown]
# ##Parameter tuning in xgboost

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBClassifier
tuned_parameters = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5, 10],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [3, 5, 8]
        }

model = XGBClassifier(learning_rate=0.02, 
                    n_estimators=200,
                    booster = 'gbtree',
                    objective='binary:logistic',
                    silent=True, 
                    nthread=-1)
skf = StratifiedKFold(n_splits=5, shuffle = False, random_state = 22)
random_search_model = RandomizedSearchCV(estimator = model, 
                                   param_distributions=tuned_parameters, 
                                   n_iter=500, 
                                   scoring='accuracy', 
                                   n_jobs=-1, 
                                   cv=skf.split(X_train,y_train), 
                                   verbose=3, 
                                   random_state=22)

random_search_model.fit(X_train, y_train)

y_pred = random_search_model.predict(X_test)

predictions = [round(value) for value in y_pred]
accuracy = float(np.sum(predictions==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 124 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 284 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 508 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=-1)]: Done 796 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=-1)]: Done 1148 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=-1)]: Done 1564 tasks      | elapsed: 15.8min
# [Parallel(n_jobs=-1)]: Done 2044 tasks      | elapsed: 22.0min
# [Parallel(n_jobs=-1)]: Done 2430 out of 2430 | elapsed: 27.1min finished
# accuracy: 0.807392

# %% [markdown]
# #FEATURE SELECTION

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# find best scored 5 features\
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, lables, features.index, test_size=0.2, random_state=0)
select_feature = SelectKBest(chi2, k=19).fit(X_train, y_train)
x_train_2 = select_feature.transform(X_train)
x_test_2 = select_feature.transform(X_test)
#feture selection on logistice regression
clf_rf_2 = LogisticRegression(random_state=0)   
clr_rf_2 = clf_rf_2.fit(x_train_2,y_train)
#ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
#print('Accuracy is: ',ac_2)
cm_2 = confusion_matrix(y_test,clf_rf_2.predict(x_test_2))
sns.heatmap(cm_2,annot=True,fmt="d")
accuracy = float(np.sum(clf_rf_2.predict(x_test_2)==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.807392

# %% [markdown]
# #SVM

# %%
from sklearn import svm
#Assumed you have, X (predictor) and Y (target) for training data set and x_test(predictor) of test_dataset
# Create SVM classification object 
model = svm.SVC(kernel='linear', C=1, gamma=1)
model.fit(X_train, y_train)
#y_pred_proba = model.predict_proba(X_test)
y_pred = model.predict(X_test)
conf_mat = confusion_matrix(y_test, y_pred)
sns.heatmap(conf_mat, annot=True, fmt='d',
          xticklabels=['yes','no'], yticklabels=['yes','no'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.799574

# %%
#FEATURE SELECTION FOR RANDOM FOREST
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# find best scored 5 features\
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, lables, features.index, test_size=0.2, random_state=0)
select_feature = SelectKBest(chi2, k=7).fit(X_train, y_train)
x_train_2 = select_feature.transform(X_train)
x_test_2 = select_feature.transform(X_test)
#random forest classifier with n_estimators=10 (default)
model = RandomForestClassifier()
model.fit(x_train_2,y_train)
y_pred = model.predict(x_test_2)
#ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
#print('Accuracy is: ',ac_2)
cm_2 = confusion_matrix(y_test,clf_rf_2.predict(x_test_2))
sns.heatmap(cm_2,annot=True,fmt="d")
accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
features
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-3b53c0bc4168> in <module>()
#      13 #ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
#      14 #print('Accuracy is: ',ac_2)
# ---> 15 cm_2 = confusion_matrix(y_test,clf_rf_2.predict(x_test_2))
#      16 sns.heatmap(cm_2,annot=True,fmt="d")
#      17 accuracy = float(np.sum(y_pred==y_test))/y_test.shape[0]
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/base.py in predict(self, X)
#     279             Predicted class label per sample.
#     280         """
# --> 281         scores = self.decision_function(X)
#     282         if len(scores.shape) == 1:
#     283             indices = (scores > 0).astype(np.int)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     260         if X.shape[1] != n_features:
# ...

# %% [markdown]
# #feature selection on xgboost

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# find best scored 5 features\
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test, indices_train, indices_test = train_test_split(features, lables, features.index, test_size=0.2, random_state=0)
select_feature = SelectKBest(chi2, k=7).fit(X_train, y_train)
x_train_2 = select_feature.transform(X_train)
x_test_2 = select_feature.tifier
model = XGBClassifier()ransform(X_test)
clf_rf_2 =XGBClassifier()
clr_rf_2 = clf_rf_2.fit(x_train_2,y_train)
#ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
#print('Accuracy is: ',ac_2)
cm_2 = confusion_matrix(y_test,clf_rf_2.predict(x_test_2))
sns.heatmap(cm_2,annot=True,fmt="d")
accuracy = float(np.sum(clf_rf_2.predict(x_test_2)==y_test))/y_test.shape[0]
print("accuracy: %f" % (accuracy))
# Out:
# accuracy: 0.818053

# %% [markdown]
# #ARTIFICIAl  NURAL NETWORK

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 19))

# Adding the second hidden layer
classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)

# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 5625/5625 [==============================] - 5s 802us/step - loss: 0.5634 - acc: 0.7394
# Epoch 2/100
# 5625/5625 [==============================] - 3s 452us/step - loss: 0.4996 - acc: 0.7778
# Epoch 3/100
# 5625/5625 [==============================] - 3s 451us/step - loss: 0.4632 - acc: 0.7835
# Epoch 4/100
# 5625/5625 [==============================] - 3s 446us/step - loss: 0.4511 - acc: 0.7906
# Epoch 5/100
# 5625/5625 [==============================] - 3s 450us/step - loss: 0.4480 - acc: 0.7897
# Epoch 6/100
# 5625/5625 [==============================] - 3s 451us/step - loss: 0.4455 - acc: 0.7916
# Epoch 7/100
# 5625/5625 [==============================] - 3s 459us/step - loss: 0.4421 - acc: 0.7899
# Epoch 8/100
# 5625/5625 [==============================] - 3s 456us/step - loss: 0.4366 - acc: 0.7957
# Epoch 9/100
# 5625/5625 [==============================] - 3s 459us/step - loss: 0.4311 - acc: 0.7998
# Epoch 10/100
# ...

# %%
sns.heatmap(cm,annot=True,fmt="d")
# = float(np.sum(y_pred==y_test))/y_test.shape[0]
#print("accuracy: %f" % (accuracy))
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8009950248756219

# %%
numerics = df[['tenure','MonthlyCharges', 'TotalCharges', 'Churn']]

plt.figure(figsize = (8,8))

sns.regplot(x = 'tenure', y = 'TotalCharges', data = numerics)

plt.title('Relationship between loyalty months and total revenue')
# Out:
# Text(0.5, 1.0, 'Relationship between loyalty months and total revenue')

# %%
plt.figure(figsize = (8,8))
sns.set(style = 'whitegrid')

sns.countplot(df.SeniorCitizen, hue = df.Churn )

# %%
plt.figure(figsize = (10,8))

sns.set(style = 'whitegrid')
sns.boxplot(x = df.SeniorCitizen, y = df.TotalCharges, hue = df.Churn)

plt.title('Total Revenue by Seniors and Non-Seniors')
# Out:
# Text(0.5, 1.0, 'Total Revenue by Seniors and Non-Seniors')
